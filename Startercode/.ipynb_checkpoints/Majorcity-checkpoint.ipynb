# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Name of the CSV file
file = 'data/GlobalLandTemperaturesByMajorCity.csv'
file
# Out:
# 'data/GlobalLandTemperaturesByMajorCity.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
# Preview of the DataFrame
# Note that FIELD8 is likely a meaningless column
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#           Country Latitude Longitude
# 0  CÃ´te D'Ivoire    5.63N     3.23W
# 1  CÃ´te D'Ivoire    5.63N     3.23W
# 2  CÃ´te D'Ivoire    5.63N     3.23W
# 3  CÃ´te D'Ivoire    5.63N     3.23W
# 4  CÃ´te D'Ivoire    5.63N     3.23W

# %%
# The Amount column is the wrong data type. It should be numeric.
df.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object

# %%
# Drop all rows with missing information
df = df.dropna(how='any')

# %%
# Verify dropped rows
df.count()
# Out:
# dt                               228175
# AverageTemperature               228175
# AverageTemperatureUncertainty    228175
# City                             228175
# Country                          228175
# Latitude                         228175
# Longitude                        228175
# dtype: int64

# %%
df.head(10)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
# 5  1849-06-01              24.844                          1.402  Abidjan
# 6  1849-07-01              24.058                          1.254  Abidjan
# 7  1849-08-01              23.576                          1.265  Abidjan
# 8  1849-09-01              23.662                          1.226  Abidjan
# 9  1849-10-01              25.263                          1.175  Abidjan
#
#           Country Latitude Longitude
# 0  CÃ´te D'Ivoire    5.63N     3.23W
# 1  CÃ´te D'Ivoire    5.63N     3.23W
# 2  CÃ´te D'Ivoire    5.63N     3.23W
# ...

# %%
new_df =df.loc[df["dt"] >= "1900-01-01", :]
new_df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 613  2/1/1900              27.816                          0.789  Abidjan
# 614  3/1/1900              28.395                          1.296  Abidjan
# 615  4/1/1900              27.706                          0.501  Abidjan
# 616  5/1/1900              26.753                          0.458  Abidjan
# 617  6/1/1900              25.180                          0.733  Abidjan
#
#             Country Latitude Longitude
# 613  CÃ´te D'Ivoire    5.63N     3.23W
# 614  CÃ´te D'Ivoire    5.63N     3.23W
# 615  CÃ´te D'Ivoire    5.63N     3.23W
# 616  CÃ´te D'Ivoire    5.63N     3.23W
# 617  CÃ´te D'Ivoire    5.63N     3.23W

# %%
#Dropping duplicates
new_df.drop_duplicates(subset=None, keep='first', inplace=False)
new_df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 613  2/1/1900              27.816                          0.789  Abidjan
# 614  3/1/1900              28.395                          1.296  Abidjan
# 615  4/1/1900              27.706                          0.501  Abidjan
# 616  5/1/1900              26.753                          0.458  Abidjan
# 617  6/1/1900              25.180                          0.733  Abidjan
#
#             Country Latitude Longitude
# 613  CÃ´te D'Ivoire    5.63N     3.23W
# 614  CÃ´te D'Ivoire    5.63N     3.23W
# 615  CÃ´te D'Ivoire    5.63N     3.23W
# 616  CÃ´te D'Ivoire    5.63N     3.23W
# 617  CÃ´te D'Ivoire    5.63N     3.23W

# %%
new_df.count()
# Out:
# dt                               91107
# AverageTemperature               91107
# AverageTemperatureUncertainty    91107
# City                             91107
# Country                          91107
# Latitude                         91107
# Longitude                        91107
# dtype: int64

# %%
new_df =df.loc[df["dt"] >= "1900-01-01", :]
new_df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 613  2/1/1900              27.816                          0.789  Abidjan
# 614  3/1/1900              28.395                          1.296  Abidjan
# 615  4/1/1900              27.706                          0.501  Abidjan
# 616  5/1/1900              26.753                          0.458  Abidjan
# 617  6/1/1900              25.180                          0.733  Abidjan
#
#             Country Latitude Longitude
# 613  CÃ´te D'Ivoire    5.63N     3.23W
# 614  CÃ´te D'Ivoire    5.63N     3.23W
# 615  CÃ´te D'Ivoire    5.63N     3.23W
# 616  CÃ´te D'Ivoire    5.63N     3.23W
# 617  CÃ´te D'Ivoire    5.63N     3.23W

# %%
city_count=new_df['City'].unique()

# %%
city_count
# Out:
# array(['Abidjan', 'Addis Abeba', 'Ahmadabad', 'Aleppo', 'Alexandria',
#        'Ankara', 'Baghdad', 'Bangalore', 'Bangkok', 'Belo Horizonte',
#        'Berlin', 'BogotÃ¡', 'Bombay', 'BrasÃ\xadlia', 'Cairo', 'Calcutta',
#        'Cali', 'Cape Town', 'Casablanca', 'Changchun', 'Chengdu',
#        'Chicago', 'Chongqing', 'Dakar', 'Dalian', 'Dar Es Salaam',
#        'Delhi', 'Dhaka', 'Durban', 'Faisalabad', 'Fortaleza', 'Gizeh',
#        'Guangzhou', 'Harare', 'Harbin', 'Ho Chi Minh City', 'Hyderabad',
#        'Ibadan', 'Istanbul', 'Izmir', 'Jaipur', 'Jakarta', 'Jiddah',
#        'Jinan', 'Kabul', 'Kano', 'Kanpur', 'Karachi', 'Kiev', 'Kinshasa',
#        'Lagos', 'Lahore', 'Lakhnau', 'Lima', 'London', 'Los Angeles',
#        'Luanda', 'Madras', 'Madrid', 'Manila', 'Mashhad', 'Melbourne',
#        'Mexico', 'Mogadishu', 'Montreal', 'Moscow', 'Nagoya', 'Nagpur',
#        'Nairobi', 'Nanjing', 'New Delhi', 'New York', 'Paris', 'Peking',
# ...

# %%
new_df.set_index('City')
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# City
# Abidjan  2/1/1900              27.816                          0.789
# Abidjan  3/1/1900              28.395                          1.296
# Abidjan  4/1/1900              27.706                          0.501
# Abidjan  5/1/1900              26.753                          0.458
# Abidjan  6/1/1900              25.180                          0.733
# Abidjan  7/1/1900              24.192                          0.828
# Abidjan  8/1/1900              23.473                          1.209
# Abidjan  9/1/1900              25.127                          0.658
# Abidjan  2/1/1901              27.913                          0.772
# Abidjan  3/1/1901              27.512                          1.178
# Abidjan  4/1/1901              26.816                          1.270
# Abidjan  5/1/1901              25.837                          0.770
# ...

# %%
new_df.groupby['dt'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-900bbf0c9feb> in <module>
# ----> 1 new_df.groupby['dt'].mean()
#
# TypeError: 'method' object is not subscriptable
